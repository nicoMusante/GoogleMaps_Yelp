# %%
import pandas as pd

# %% [markdown]
# Verificacion archivo "checkin.json"

# %%
data_chekin=pd.read_json(r"C:\Users\Usuario\Desktop\GitHub\DataSets\DataLake\YELP\Yelp\checkin.json", lines=True)

# %%
data_chekin.shape
# Out:
# (131930, 2)

# %%
data_chekin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131930 entries, 0 to 131929
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   business_id  131930 non-null  object
#  1   date         131930 non-null  object
# dtypes: object(2)
# memory usage: 2.0+ MB

# %%
data_chekin.head(2)
# Out:
#               business_id                                               date
# 0  ---kPU91CF4Lq2-WlRu9Lw  2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1  --0iUa4sNDFiZFrAdIWhZQ  2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...

# %% [markdown]
# Mediante un pequeño analisis exploratorio, se observan dos columnas pertinentes a "business_id" (se presume un ID), "date"(conteniendo fechas y horarios, presumiendo regsitros)

# %% [markdown]
# Verificacion archivo "tip.json"

# %%
data_tip=pd.read_json(r"C:\Users\Usuario\Desktop\GitHub\DataSets\DataLake\YELP\Yelp\tip.json", lines=True)

# %%
data_tip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908915 entries, 0 to 908914
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           908915 non-null  object
#  1   business_id       908915 non-null  object
#  2   text              908915 non-null  object
#  3   date              908915 non-null  datetime64[ns]
#  4   compliment_count  908915 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 34.7+ MB

# %%
data_tip.head(5)
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3  FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4  ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
#
#                                                 text                date  \
# 0                     Avengers time with the ladies. 2012-05-18 02:17:21
# 1  They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# 2             It's open even when you think it isn't 2013-08-18 00:56:08
# 3                          Very decent fried chicken 2017-06-27 23:05:38
# 4             Appetizers.. platter special for lunch 2012-10-06 19:43:09
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %% [markdown]
# Tratamiento para la columna "compliment_count"

# %%
frecuencia_valores = data_tip['compliment_count'].value_counts()

print("Frecuencia de cada valor distinto en 'compliment_count':")
print(frecuencia_valores)
# Out:
# Frecuencia de cada valor distinto en 'compliment_count':
# compliment_count
# 0    898376
# 1      9821
# 2       617
# 3        82
# 4        14
# 5         3
# 6         2
# Name: count, dtype: int64

# %% [markdown]
# Se pueden observar las columnas "user_id"(ids de usuarios),	"business_id"(id de locales), "text"(comentario de usuario sobre local),"date"(dia y hora del comentario), "compliment_count"(sentimiento preliminar del comentario o valoracion, la cual de un analisis se observa muy poca informacion pertinente y se decide eliminar)

# %% [markdown]
# Verificacion archivo "review-002.json"

# %%
data_review002=pd.read_json(r"C:\Users\Usuario\Desktop\GitHub\DataSets\DataLake\YELP\review-002.json", lines=True, nrows=100)

# %%
data_review002.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   review_id    100 non-null    object
#  1   user_id      100 non-null    object
#  2   business_id  100 non-null    object
#  3   stars        100 non-null    int64
#  4   useful       100 non-null    int64
#  5   funny        100 non-null    int64
#  6   cool         100 non-null    int64
#  7   text         100 non-null    object
#  8   date         100 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 7.2+ KB

# %%
data_review002.head(4)
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03

# %% [markdown]
# Verificacion archivo "business.pkl"

# %%
data_bussines=pd.read_pickle(r"C:\Users\Usuario\Desktop\GitHub\DataSets\DataLake\YELP\Yelp\business.pkl")

# %%
data_bussines.shape
# Out:
# (150346, 28)

# %%
data_bussines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
# ...

# %%
data_bussines.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours', 'business_id', 'name', 'address',
#        'city', 'state', 'postal_code', 'latitude', 'longitude', 'stars',
#        'review_count', 'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
data_bussines.head(2)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
#
#   longitude stars review_count is_open attributes categories hours
# 0       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 1       NaN   NaN          NaN     NaN        NaN        NaN   NaN
#
# [2 rows x 28 columns]

# %% [markdown]
# Mediante el analisis anterior preliminar, se observa una repeticion  de columnas, las cuales ademas poseen en su mayoria datos nulos o faltantes, se recomienda la eliminacion de dichas columnas en el proceso de ETL. ('business_id', 'name', 'address','city', 'state', 'postal_code', 'latitude', 'longitude', 'stars','review_count', 'is_open', 'attributes', 'categories', 'hours')

# %%
primeras_14_columnas = data_bussines.iloc[:, :14]
primeras_14_columnas
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %% [markdown]
# Se observan las columnas "attributes" conteniendo atributos personales de cada local, y columna "hours" con el horario de atencion, las cuales no poseen informacion pertinente para nuestro futuro analisis, por consiguiente, se recomienda su eliminacion, ademas de la columna postal_code ya que contiene informacion redundante

# %% [markdown]
# Verificacion archivo "user-001.parquet"

# %%
data_user001=pd.read_parquet(r"C:\Users\Usuario\Desktop\GitHub\DataSets\DataLake\YELP\user-001.parquet")

# %%
data_user001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105597 entries, 0 to 2105596
# Data columns (total 22 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   user_id             object
#  1   name                object
#  2   review_count        int64
#  3   yelping_since       object
#  4   useful              int64
#  5   funny               int64
#  6   cool                int64
#  7   elite               object
#  8   friends             object
#  9   fans                int64
#  10  average_stars       float64
#  11  compliment_hot      int64
#  12  compliment_more     int64
#  13  compliment_profile  int64
#  14  compliment_cute     int64
#  15  compliment_list     int64
#  16  compliment_note     int64
#  17  compliment_plain    int64
#  18  compliment_cool     int64
#  19  compliment_funny    int64
#  20  compliment_writer   int64
#  21  compliment_photos   int64
# dtypes: float64(1), int64(16), object(5)
# memory usage: 353.4+ MB

# %%
data_user001.shape
# Out:
# (2105597, 22)

# %%
data_user001.columns
# Out:
# Index(['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny',
#        'cool', 'elite', 'friends', 'fans', 'average_stars', 'compliment_hot',
#        'compliment_more', 'compliment_profile', 'compliment_cute',
#        'compliment_list', 'compliment_note', 'compliment_plain',
#        'compliment_cool', 'compliment_funny', 'compliment_writer',
#        'compliment_photos'],
#       dtype='object')

# %%
data_user001.head(5)
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# ...

# %% [markdown]
# Dado que uno de los objetivos planteados con anterioridad, en la planificacion de un modelo de Machine Learning basados en un sistema de recomendacion, se decide dejar este Dataset sin modificaciones iniciales, ya que cuenta con informacion que podremos llegar a analizar para dicho proposito.
