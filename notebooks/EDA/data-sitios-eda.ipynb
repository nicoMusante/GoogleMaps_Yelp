# %%
import pandas as pd

# %%
data=pd.read_json(r".\DataSets\DataLake\GOOGLE\DATA SITIOS\metadata-sitios\1.json", encoding="utf-8", lines=True)

# %%
data.head(5)
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#               category  avg_rating  num_of_reviews price  \
# ...

# %% [markdown]
# Se explora la columna "category" a fin de conocer la estructura y poder seleccionar las categorias que nos interesan

# %%
data["category"]
# Out:
# 0                                                [Pharmacy]
# 1                                        [Textile exporter]
# 2                                       [Korean restaurant]
# 3                                            [Fabric store]
# 4                                            [Fabric store]
#                                 ...
# 274996                                 [Real estate agency]
# 274997    [Fence contractor, Construction company, Contr...
# 274998                            [Health insurance agency]
# 274999    [Building materials store, Electrical supply s...
# 275000                                   [Auto repair shop]
# Name: category, Length: 275001, dtype: object

# %%
exploded_data = data.explode('category')
print(exploded_data)
# Out:
#                                  name  \
# 0                     Porter Pharmacy
# 1                        City Textile
# 2                        San Soo Dang
# 3                        Nova Fabrics
# 4                    Nobel Textile Co
# ...                               ...
# 274999        Bernard Building Center
# 274999        Bernard Building Center
# 274999        Bernard Building Center
# 274999        Bernard Building Center
# 275000  HMR Motor Works and Auto Care
#
#                                                   address  \
# 0       Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1       City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2       San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3       Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4       Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                                                   ...
# 274999  Bernard Building Center, 27300 M-32, M-32, Hil...
# ...

# %%
category_counts = exploded_data['category'].value_counts()
category_counts
# Out:
# category
# Service establishment       10055
# Beauty salon                 5612
# Auto repair shop             5499
# Restaurant                   5386
# Church                       5349
#                             ...
# Orchid farm                     1
# Soapland                        1
# Ferris wheel                    1
# Leather goods wholesaler        1
# Cane furniture store            1
# Name: count, Length: 3769, dtype: int64

# %%
exploded_data[exploded_data["category"]=="Restaurant"].head(2)
#restaurant, bar, pub, cafe
# Out:
#                name                                            address  \
# 6      Vons Chicken  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 68  Vivi Bubble Tea  Vivi Bubble Tea, 701 S 5th St, Philadelphia, P...
#
#                                   gmap_id  \
# 6   0x80dd2b4c8555edb7:0xfc33d65c4bdbef42
# 68  0x89c6c89efcaed69d:0xded973f6033e7dba
#
#                                           description   latitude   longitude  \
# 6                                                None  33.916402 -118.010855
# 68  Bubble tea shop offering hot & cold versions, ...  39.940293  -75.150923
#
#       category  avg_rating  num_of_reviews price  \
# 6   Restaurant         4.5              18  None
# 68  Restaurant         4.0               8  None
#
#                                                 hours  \
# 6   [[Thursday, 11AM–9:30PM], [Friday, 11AM–9:30PM...
# 68                                               None
#
# ...

# %%
exploded_data[exploded_data["category"]=="Bar"].head(2)
# Out:
#                    name                                            address  \
# 75        The Bar Stool     The Bar Stool, 618 Main St, Highland, WI 53543
# 179  Richmond House Pub  Richmond House Pub, N6496 WI-89, Delavan, WI 5...
#
#                                    gmap_id description   latitude  longitude  \
# 75   0x87fd0e70c5f5d87b:0xdf340eeb75040ef3        None  43.046428 -90.380139
# 179  0x8805e31e080da871:0xaa8ce3d6b6d0032f        None  42.725457 -88.748811
#
#     category  avg_rating  num_of_reviews price hours  \
# 75       Bar         4.5              18  None  None
# 179      Bar         1.0               1  None  None
#
#                                                   MISC state  \
# 75   {'Service options': ['Dine-in', 'Delivery'], '...  None
# 179  {'Highlights': ['Bar games', 'Fast service', '...  None
#
#                                       relative_results  \
# 75   [0x87fd0e70dc5eeb3d:0x7f3ce1daba0a5f24, 0x87fd...
# ...

# %%
exploded_data[exploded_data["category"]=="Pub"].head(2)
# Out:
#                       name                                            address  \
# 2046  Hail Mary Sports Pub  Hail Mary Sports Pub, 1950 Grayson Hwy # 140, ...
# 5023      TheBarsOfAmerica  TheBarsOfAmerica, Online Pickup, Las Vegas, NV...
#
#                                     gmap_id description   latitude  \
# 2046  0x88f5b8c16aff7eb3:0x36ce3e50ab6b9f35        None  33.897581
# 5023  0x80c8cf0fffffffff:0x4e446fa30178181b        None  36.196312
#
#        longitude category  avg_rating  num_of_reviews price  \
# 2046  -83.959038      Pub         3.5              17  None
# 5023 -115.238775      Pub         3.9               8  None
#
#                                                   hours  \
# 2046                                               None
# 5023  [[Wednesday, 10:30AM–1AM], [Thursday, 10:30AM–...
#
#                                                    MISC              state  \
# 2046  {'Service options': ['Dine-in'], 'Offerings': ...               None
# ...

# %%
exploded_data[exploded_data["category"]=="Cafe"].head(2)
# Out:
#                             name  \
# 883   Daily Dose Craft Bar, Inc.
# 1073                  G & S Cafe
#
#                                                 address  \
# 883   Daily Dose Craft Bar, Inc., 11643 Beach Blvd U...
# 1073    G & S Cafe, 25 Sigourney St, Hartford, CT 06106
#
#                                     gmap_id description   latitude  longitude  \
# 883   0x88e5b53b107a2609:0x40106d3b48960d9d        None  30.287836 -81.517501
# 1073  0x89e6534451cfa24f:0x543b1ed69e88390b        None  41.762713 -72.694573
#
#      category  avg_rating  num_of_reviews price  \
# 883      Cafe         5.0              27  None
# 1073     Cafe         1.0               1  None
#
#                                                   hours  \
# 883   [[Thursday, 10AM–8PM], [Friday, 10AM–8PM], [Sa...
# 1073  [[Thursday, 7AM–4:30PM], [Friday, 7AM–4:30PM],...
#
#                                                    MISC                state  \
# ...

# %%
exploded_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 532733 entries, 0 to 275000
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              532726 non-null  object
#  1   address           502975 non-null  object
#  2   gmap_id           532733 non-null  object
#  3   description       43970 non-null   object
#  4   latitude          532733 non-null  float64
#  5   longitude         532733 non-null  float64
#  6   category          530472 non-null  object
#  7   avg_rating        532733 non-null  float64
#  8   num_of_reviews    532733 non-null  int64
#  9   price             44374 non-null   object
#  10  hours             428211 non-null  object
#  11  MISC              401058 non-null  object
#  12  state             432206 non-null  object
#  13  relative_results  475847 non-null  object
#  14  url               532733 non-null  object
# dtypes: float64(3), int64(1), object(11)
# ...
