# %%
import pandas as pd

# %%
data=pd.read_json(r"C:\Users\Usuario\Desktop\PROYECTO_FINAL\GOOGLE\DATA SITIOS\metadata-sitios\1.json", encoding="utf-8", lines=True)

# %%
data.head(10)
# Out:
#                                     name  \
# 0                        Porter Pharmacy
# 1                           City Textile
# 2                           San Soo Dang
# 3                           Nova Fabrics
# 4                       Nobel Textile Co
# 5          Matrix International Textiles
# 6                           Vons Chicken
# 7              Polished Nail Salon & Spa
# 8  Sweet Rewards Gluten Free Bakery, LLC
# 9                              PeepNotes
#
#                                              address  \
# 0  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# 5  Matrix International Textiles, 1363 S Bonnie B...
# 6  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 7  Polished Nail Salon & Spa, 1330 Hickman Rd, Wa...
# ...

# %% [markdown]
# Se explora la columna "category" a fin de conocer la estructura y poder seleccionar las categorias que nos interesan

# %%
data["category"]
# Out:
# 0                                                [Pharmacy]
# 1                                        [Textile exporter]
# 2                                       [Korean restaurant]
# 3                                            [Fabric store]
# 4                                            [Fabric store]
#                                 ...
# 274996                                 [Real estate agency]
# 274997    [Fence contractor, Construction company, Contr...
# 274998                            [Health insurance agency]
# 274999    [Building materials store, Electrical supply s...
# 275000                                   [Auto repair shop]
# Name: category, Length: 275001, dtype: object

# %%
exploded_data = data.explode('category')
print(exploded_data)
# Out:
#                                  name  \
# 0                     Porter Pharmacy
# 1                        City Textile
# 2                        San Soo Dang
# 3                        Nova Fabrics
# 4                    Nobel Textile Co
# ...                               ...
# 274999        Bernard Building Center
# 274999        Bernard Building Center
# 274999        Bernard Building Center
# 274999        Bernard Building Center
# 275000  HMR Motor Works and Auto Care
#
#                                                   address  \
# 0       Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1       City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2       San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3       Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4       Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                                                   ...
# 274999  Bernard Building Center, 27300 M-32, M-32, Hil...
# ...

# %%
category_counts = exploded_data['category'].value_counts()
category_counts
# Out:
# category
# Service establishment       10055
# Beauty salon                 5612
# Auto repair shop             5499
# Restaurant                   5386
# Church                       5349
#                             ...
# Orchid farm                     1
# Soapland                        1
# Ferris wheel                    1
# Leather goods wholesaler        1
# Cane furniture store            1
# Name: count, Length: 3769, dtype: int64

# %%
exploded_data[exploded_data["category"]=="Confectionery"]
# Out:
#                                                      name  \
# 58658                              Sugarfina at Nordstrom
# 92544   SweetWorks Confections LLC Corporate Headquarters
# 134163                               European Confections
# 137184           Woops! Macarons & Gifts (Newport Centre)
# 141504                           Sweet Thangs Nut & Candy
# 186772                              Crepe & Candy Station
# 193455                                          Sugarfina
# 202122                                 Sweet pick and mix
# 241946                                         LibbyBeans
# 244143          Woops! Macarons & Gifts (Opry Mills Mall)
# 249138                                          Sugarfina
# 251373              Jean Pierre's - Fine Chocolate & Nuts
# 267471         Woops! Macarons & Gifts (Penn Square Mall)
#
#                                                   address  \
# 58658   Sugarfina at Nordstrom, 55 E Grand Ave, Chicag...
# ...

# %%
data[data["name"]=="Shin-Sen-Gumi 2GO"]
# Out:
#                      name                                            address  \
# 274962  Shin-Sen-Gumi 2GO  Shin-Sen-Gumi 2GO, Marukai, 1620 W Redondo Bea...
#
#                                       gmap_id  \
# 274962  0x80c2b5826663f60d:0x969ceb2d88ae4623
#
#                                               description   latitude  \
# 274962  Informal Japanese chain serving charcoal-grill...  33.888211
#
#          longitude                                           category  \
# 274962 -118.304874  [Ramen restaurant, Japanese restaurant, Restau...
#
#         avg_rating  num_of_reviews price  \
# 274962         4.3               8     $
#
#                                                     hours  \
# 274962  [[Saturday, 10AM–10PM], [Sunday, 10AM–10PM], [...
#
#                                                      MISC               state  \
# 274962  {'Service options': ['Delivery'], 'Popular for...  Permanently closed
#
# ...
